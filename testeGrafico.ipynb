# %%
import matplotlib.pyplot as plt
nomes = ['Yago', 'Primo', 'Alice']
idades = [21, 17, 32]

plt.plot(nomes,idades)

# %%
plt.figure(figsize=(4,4))
plt.bar(nomes,idades)
plt.xlabel('Nome')
plt.ylabel('Idade')
# Out:
# Text(0, 0.5, 'Idade')
